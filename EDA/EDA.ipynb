# %%
# Import the libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datset
path = "../Data/Final_data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Age  Gender Smoking_Status  Family_History_COPD    BMI   Location  \
# 0   31    Male         Former                    1  27.56   Lalitpur
# 1   60    Male          Never                    0  30.30    Pokhara
# 2   33    Male         Former                    1  28.45    Pokhara
# 3   36  Female        Current                    0  27.49  Kathmandu
# 4   58    Male          Never                    0  25.49    Pokhara
#
#    Air_Pollution_Level  COPD_Diagnosis
# 0                   84               0
# 1                  131               0
# 2                  123               0
# 3                  253               1
# 4                  117               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  1000 non-null   int64
#  1   Gender               1000 non-null   object
#  2   Smoking_Status       1000 non-null   object
#  3   Family_History_COPD  1000 non-null   int64
#  4   BMI                  1000 non-null   float64
#  5   Location             1000 non-null   object
#  6   Air_Pollution_Level  1000 non-null   int64
#  7   COPD_Diagnosis       1000 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 62.6+ KB

# %%
# set up a large plot for better visibilty

plt.figure(figsize=(14,8))

# %% [markdown]
# ## Univariate Analysys

# %%
sns.histplot(df['Age'], kde = True, color='yellow')
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
# BMI Distribution

sns.histplot(df['BMI'], kde= True, color="blue")
plt.title("BMI Distribution")
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %%
# gender distribution
sns.countplot(x= 'Gender', data= df, palette='viridis')
plt.title("Gender Distribution")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25120\271141478.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= 'Gender', data= df, palette='viridis')
# Text(0.5, 1.0, 'Gender Distribution')

# %%
sns.countplot(x= 'Smoking_Status', data= df, palette='coolwarm')
plt.title("Smoking Status")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25120\1406791592.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= 'Smoking_Status', data= df, palette='coolwarm')
# Text(0.5, 1.0, 'Smoking Status')

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.figure(figsize=(14,10))

# %%
# Age vs COPD Diagnosis

sns.boxplot(x='COPD_Diagnosis', y= 'Age', data= df, palette='viridis')
plt.title("Age  VS COPD Diagnosis")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25120\4053063151.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='COPD_Diagnosis', y= 'Age', data= df, palette='viridis')
# Text(0.5, 1.0, 'Age  VS COPD Diagnosis')

# %%
# BMI vs COPD Diagnosis
sns.boxplot(x='COPD_Diagnosis', y= 'BMI', data= df, palette='coolwarm')
plt.title("BMI  VS COPD Diagnosis")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25120\221904540.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='COPD_Diagnosis', y= 'BMI', data= df, palette='coolwarm')
# Text(0.5, 1.0, 'BMI  VS COPD Diagnosis')

# %%
sns.countplot(x = 'COPD_Diagnosis', data= df, palette='viridis')
plt.title("Count plot of COPD Diagnosis")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_25120\4100792417.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'COPD_Diagnosis', data= df, palette='viridis')

# %%
# Corelation Matrix
data_corr= df[['Age', 'Family_History_COPD', 'BMI', 'Air_Pollution_Level', 'COPD_Diagnosis']]
corr = data_corr.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Corrlation Matrix")
plt.show()

# %%
# pair plot 
sns.pairplot(df, hue='COPD_Diagnosis', diag_kind='kde', palette='Set1')
plt.title("Pair Plot")
plt.show()
